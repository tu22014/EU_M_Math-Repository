# %% [markdown]
# <a href="https://colab.research.google.com/github/tu22014/EU_M_Math-Repository/blob/main/chap02_Ex10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

#小数点第3位まで表示
# %precision 3

#(2-10)
#MatplotlibとSeabornの読み込み
import matplotlib as mpl
import seaborn as sns

#pyplotをpltの別名で実行できるようにする
import matplotlib.pyplot as plt

#関数の定義
def practice2_10(x):
  return (x * 5 + 3)

x = np.linspace(-10, 10, 100)
plt.figure(figsize = (20, 6))
plt.plot(x, practice2_10(x))
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
