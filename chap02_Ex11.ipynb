# %% [markdown]
# <a href="https://colab.research.google.com/github/tu22014/EU_M_Math-Repository/blob/main/chap02_Ex11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

#小数点第3位まで表示
# %precision 3

#MatplotlibとSeabornの読み込み
import matplotlib as mpl
import seaborn as sns

#pyplotをpltの別名で実行できるようにする
import matplotlib.pyplot as plt

#(2-11)
#グラフの大きさ指定
plt.figure(figsize = (20, 6))
#xの座標名
plt.xlabel('X')
#yの座標名
plt.ylabel('Y')
#-10から10までの数を100個に分割した数字リスト
x = np.linspace(-10, 10, 100)
#sinxの描画
plt.plot(x, np.sin(x))
#cosxの描画
plt.plot(x, np.cos(x))
#グリッド表示
plt.grid(True)
