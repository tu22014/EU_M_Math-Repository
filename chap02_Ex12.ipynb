# %% [markdown]
# <a href="https://colab.research.google.com/github/tu22014/EU_M_Math-Repository/blob/main/chap02_Ex12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

#小数点第3位まで表示
# %precision 3

#MatplotlibとSeabornの読み込み
import matplotlib as mpl
import seaborn as sns

#pyplotをpltの別名で実行できるようにする
import matplotlib.pyplot as plt

#(2-12)
#0から1の一様乱数1000個2組の生成
random.seed(0)
practice2_12_data1 = np.random.uniform(0.0, 1.0, 1000)
random.seed(10)
practice2_12_data2 = np.random.uniform(0.0, 1.0, 1000)

#グラフの大きさ指定
plt.figure(figsize = (20, 6))

plt.subplot(2, 1,  1)

plt.hist(practice2_12_data1)

plt.grid(True)

plt.subplot(2, 1, 2)

plt.hist(practice2_12_data2)

plt.grid(True)
